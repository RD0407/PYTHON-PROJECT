# %%
import numpy as np
data = np.load('/home/shared/Project_2/ice_data/20030715.npy')
data1 = np.load('/home/shared/Project_2/ice_data/20080715.npy')
data2 = np.load('/home/shared/Project_2/ice_data/20130715.npy')
data3 = np.load('/home/shared/Project_2/ice_data/20180715.npy')

# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.axes_grid1 import make_axes_locatable
from collections import OrderedDict

cmaps = OrderedDict()

# %%
cmap = plt.cm.jet
plt.imshow(data,  origin='lower', cmap=cmap)
plt.colorbar()

# %%
plt.subplot(1, 2, 1)
plt.subplots_adjust(left=None, bottom=None, right=1.5, top=None, wspace=None, hspace=None)
plt.imshow(data, origin='lower', cmap=cmap)
plt.title('Ice map from July 2003')
plt.colorbar(fraction=0.05, pad=0.05)


plt.subplot(1, 2, 2)
plt.imshow(data3, origin='lower', cmap=cmap)
plt.title('Ice map from july 2018')
plt.colorbar(fraction=0.05, pad=0.05)


plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fig.suptitle('Ice map from July 2003, 2008, 2013, 2018')


ax1.imshow(data, origin='lower', cmap=cmap)


ax2.imshow(data1, origin='lower', cmap=cmap)
ax3.imshow(data2, origin='lower', cmap=cmap)
ax4.imshow(data3, origin='lower', cmap=cmap)

for ax in fig.get_axes():
    ax.label_outer()

# %%
import glob
import ice_data
import matplotlib.image as mpimg
directory= glob.iglob(r'/home/shared/Project_2/ice_data/*.npy')
n=0
for filepath in directory: #loop for reading all files
   # print(filepath)
    n+=1
    j=n/2
print(int(j))
print(n)#we have a total of 378 maps.
# Out:
# 189
# 378

# %%
import re
from PIL import Image
from numpy import asarray
directory= glob.glob('/home/shared/Project_2/ice_data/*20030101.npy')
directory.sort()


#def data_read(filename):
#    np.load()


i=0
n=0
for filepath in directory: #loop for reading all files
   # print(filepath)
    n+=1
print(n)
fig, axs = plt.subplots(2,int(n/2), figsize=(15, 6))
fig.subplots_adjust(hspace = .5, wspace=.001)
axs = axs.ravel()
for filename in directory: #loop for reading all files
    #print(filename)
    #data = np.load(filename)
    print(data)
    for a in data:
        if a>=50:
            print(a)
    #cmap = plt.cm.jet
    #plt.imshow(data,  origin='lower', cmap=cmap)
 
    #plt.colorbar()
    
    
    #for i in range(int(n)):
    #    axs[i].contourf(data, origin='lower',cmap=cmap)
    #    axs[i].set_title(str())
    #plt.colorbar() 
#data1=asarray(data)
   #print(data1)
#for i in data1:
       # if i>=50:
           # print(data1)
# Out:
# 1
# [[nan nan nan ...  0.  0.  0.]
#  [nan nan nan ...  0.  0.  0.]
#  [nan nan nan ...  0.  0.  0.]
#  ...
#  [ 0.  0.  0. ... nan nan nan]
#  [ 0.  0.  0. ... nan nan nan]
#  [ 0.  0.  0. ... nan nan nan]]
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in greater_equal
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-d26b4c4edf33> in <module>
#      24     print(data)
#      25     for a in data:
# ---> 26         if a>=50:
#      27             print(a)
#      28     #cmap = plt.cm.jet
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
directory= glob.iglob(r'/home/shared/Project_2/ice_data/*.npy')
import re

# %%
import re
directory= glob.glob('/home/shared/Project_2/ice_data/2003*.npy')
directory.sort()

#def data_read(filename):
#    np.load()


i=0
n=0
for filepath in directory: #loop for reading all files
   # print(filepath)
    n+=1
#print(n)
times = ([])

fig, axs = plt.subplots(2,int(n/2), figsize=(15, 6))
fig.subplots_adjust(hspace = .5, wspace=.001)
axs = axs.ravel()
for filename in directory: #loop for reading all files
    #print(filename)
    data= np.load(filename)
    cmap = plt.cm.jet
    #plt.imshow(data,  origin='lower', cmap=cmap)
    #plt.colorbar()
    
    '''
    for i in range(int(n)):
        axs[i].contourf(data, origin='lower',cmap=cmap)
        axs[i].set_title(str())
    #plt.colorbar()  
  '''
    file= filename[len(filename)-12:]
    #print(file)
    year=float(file[0:4])
    month=float(file[4:6])
    day=float(file[6:8])
    d=int(day)-1
    m = int(month)-1
    #print(day, m)
    t = m/12 + d/360 
    times = np.append(times,t)
    
    
    
        
print(times)
    #print(day)
# Out:
# [0.         0.03888889 0.08333333 0.12222222 0.16666667 0.20555556
#  0.25       0.28888889 0.33333333 0.37222222 0.41666667 0.45555556
#  0.5        0.53888889 0.58333333 0.62222222 0.66666667 0.70555556
#  0.75       0.78888889 0.87222222 0.91666667 0.95555556]

# %%
directory= glob.glob('/home/shared/Project_2/ice_data/2003*.npy')
directory.sort()

d=[]
n=0
for filename in directory: #loop for reading all files 
    #print(filename)
    data = np.load(filename)
    #print(data)
    c=[]
    for a in data:
        #print(a)
        b=a[a>=50]
        #print(b)
        c=np.append(c,len(b))
    #print(np.sum(c))
    s = np.sum(c)    
    #print(c)
    d = np.append(d,s)
#print(d)    
plt.plot(times, d)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in greater_equal
#   del sys.path[0]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-f9ee1b164cfb> in <module>
#      19     d = np.append(d,s)
#      20 #print(d)
# ---> 21 plt.plot(times, d)
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2789         is not None else {}), **kwargs)
#    2790
#    2791
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# ...

# %%
area = np.load('/home/shared/Project_2/ice_data_area.npy')
cmap = plt.cm.jet
#plt.imshow(area,  origin='lower', cmap=cmap)
#plt.colorbar()

# %%
n=0
b=[]
area_array = []
for filename in directory: #loop for reading all files 
    #print(filename)
    data = np.load(filename)
    for f in area:
        f_s=[]
        for a in data:
            b=np.where(a>=99)
            d=np.sum(f[b])
            f_s=np.append(f_s, f[b].sum())
    #print(f_s.sum())
    area_array = np.append(area_array,f_s.sum())      
print(area_array)
            
       
            #n+=1
#print(n)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in greater_equal
#   # Remove the CWD from sys.path while we load stuff.
# [7243640.75750351 5632135.42827988 7762602.51133728 7669171.14292145
#  7796577.98435593 6453658.37984848 7212449.53059006 6155700.24535751
#  5340532.67282867 5457457.67176437 4685108.127388   5737611.42249298
#  2895127.55763626 2243139.50588608 2025650.08751678 1777653.47445679
#  1737074.13630295 2379291.24538422 2313915.1778717  4086860.67839813
#  6149200.37906647 5575674.07929611 7096459.08719254]

# %%
n=0
b=[]
area_array_tot = []
for filename in directory: #loop for reading all files 
    #print(filename)
    data = np.load(filename)
    for f in area:
        f_s=[]
        for a in data:
            b=np.where(a>0)
            d=np.sum(f[b])
            f_s=np.append(f_s, f[b].sum())
    #print(f_s.sum())
    area_array_tot = np.append(area_array_tot,f_s.sum())      
print(area_array_tot)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in greater
#   # Remove the CWD from sys.path while we load stuff.
# [10833014.45052147 11086846.03055763 11410754.84737587 11315906.40301514
#  11423816.65174294 11394744.43509102 11523444.5441227  11191619.19381905
#  10925935.07743073 10585857.66686821 10203103.72574806  9601190.23063469
#   8574882.74172974  7645297.66458511  6436791.16853714  5669474.81079865
#   5233890.45416641  5166023.49645996  5539626.39252853  6635883.82804489
#   8446753.0485363   9383376.56303978 10260305.30431175]

# %%
plt.plot(times, (area_array_tot))

# %%
(np.min(area_array_tot))
# Out:
# 5166023.496459961

# %%
print(area_array_tot[17])
# Out:
# 5166023.496459961

# %%
import re

directory= glob.glob('/home/shared/Project_2/ice_data/*.npy')
directory.sort()
n=0 
b=[]
area_array_tot = []
for filename in directory: #loop for reading all files 
    #print(filename)
    data = np.load(filename)
    for f in area:
        f_s=[]
        for a in data:
            b=np.where(a>0)
            d=np.sum(f[b])
            f_s=np.append(f_s, f[b].sum())
    #print(f_s.sum())
    area_array_tot = np.append(area_array_tot,f_s.sum())      
print(area_array_tot)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in greater
# [10833014.45052147 11086846.03055763 11410754.84737587 11315906.40301514
#  11423816.65174294 11394744.43509102 11523444.5441227  11191619.19381905
#  10925935.07743073 10585857.66686821 10203103.72574806  9601190.23063469
#   8574882.74172974  7645297.66458511  6436791.16853714  5669474.81079865
#   5233890.45416641  5166023.49645996  5539626.39252853  6635883.82804489
#   8446753.0485363   9383376.56303978 10260305.30431175 10744754.16415215
#  10918196.00108147 11081703.06000137 11423236.3434906  11472034.92937851
#  11361021.88905334 11446606.8310833  10936689.75113487 10651049.52736855
#  10208672.46274567  9862684.11753845  9434508.9346714   8746626.29057312
#   7753427.70455551  6557108.12902832  5582959.2061615   5064859.52756882
#   5053062.78326416  5699364.99707031  6748791.54718971  7751106.91521835
# ...

# %%
plt.plot
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-fc1b40c2322f> in <module>
#       1 import datetime as dt
# ----> 2 area_array_tot1=area_array_tot[area_array_tot[year].dt.year == 2003]
#
# TypeError: list indices must be integers or slices, not float

# %%
import re

directory= glob.glob('/home/shared/Project_2/ice_data/200*.npy')
directory.sort()
n=0
b=[]
i=np.arange(2003,2020)
area_array_tot = []
for filename in directory: #loop for reading all files 
    #print(filename)
    data = np.load(filename)
    for f in area:
        f_s=[]
        for a in data:
            for j in range(2003, len(i)):
                b[j]=np.where(a>0)
                d=np.sum(f[b[j]])
                f_s=np.append(f_s, np.sum(f[b[j]]))
                j+=1
    #print(f_s.sum())
        area_array_tot = np.append(area_array_tot,np.sum(f_s))      
print(area_array_tot)
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
import re
import glob
import numpy as np
n=0
s=0
directory= glob.glob('/home/shared/Project_2/ice_data/20*.npy')
directory.sort()
area = np.load('/home/shared/Project_2/ice_data_area.npy')
area.sort()
for filename in directory: #loop for reading all files 
    #print(filename)
    data = np.load(filename)
    a=np.argwhere(data>99)
    #print(area[a].sum())
    n+=1
print(n)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in greater
#   if sys.path[0] == '':
# 378

# %%
data = np.load(filename)
    for f in area:
        f_s=[]
        a=np.argwhere(data>=99)
    
        d=np.sum(f[a])
        f_s=np.append(f_s, f[a].sum())
    area_array_tot = np.append(area_array_tot,f_s.sum())      
print(area_array_tot)
# Out:
#   File "<ipython-input-32-b7f1af9a82cc>", line 2
#     for f in area:
#     ^
# IndentationError: unexpected indent

# %%
import re
import glob
import numpy as np
n=0
year1=["2003", "2004", "2005", "2006","2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019"]
print(type(year1))
# Out:
# <class 'list'>
